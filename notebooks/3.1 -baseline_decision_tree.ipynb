# %% [markdown]
# # Baseline Decision Tree - Student Dropout Prediction
#
# This notebook implements a **Baseline Decision Tree** algorithm using default hyperparameters. This serves as our starting point for comparing with more optimized versions.

# %%
import sys
from pathlib import Path

# Ensure the project root is in the Python path for utils import
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import utils

# Ensure necessary directories exist
utils.ensure_directories()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       7     sys.path.append(str(PROJECT_ROOT))
#       8
#       9 import pandas as pd
#      10 from sklearn.tree import DecisionTreeClassifier
# ---> 11 import utils
#      12
#      13 # Ensure necessary directories exist
#      14 utils.ensure_directories()
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# ## 1. Load Data
#
# We load the pre-split and processed datasets from the `data/` directory.

# %%
X_train, X_test, y_train, y_test = utils.load_processed_data()

print(f"Training set shape: {X_train.shape}")
print(f"Testing set shape: {X_test.shape}")

# %% [markdown]
# ## 2. Train Baseline Model
#
# We train a `DecisionTreeClassifier` with default settings (except for `random_state` for reproducibility).

# %%
dt_model = DecisionTreeClassifier(random_state=42)

metrics, summary_df = utils.train_and_evaluate(
    model=dt_model, 
    model_name="Decision Tree Baseline"
)

# %% [markdown]
# ## 3. Results Overview
#
# Let's look at the final performance metrics on the test set.

# %%
display(summary_df)

# %% [markdown]
# ## 4. Visualizing Performance
#
# The confusion matrix provides insight into how the model misclassifies instances across different classes.

# %%
from IPython.display import Image
Image(filename=metrics["Confusion Matrix Figure"])
